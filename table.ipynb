# %%
import pandas as pd 

df = pd.read_csv('/home/jorgeda/Downloads/1-Seminario-matemáticas-aplicadas-2020-08-20.csv')
df.head()
# Out:
#                                    Unnamed: 0  \
# 0  <h4 style="text-align: center;">Fecha</h4>
# 1                         09 de Julio de 2020
# 2                             28 de mayo 2020
# 3                             28 de mayo 2020
# 4                                22 Mayo 2020
#
#                                           Unnamed: 1  \
# 0     <h4 style="text-align: center;">Expositor</h4>
# 1                    Gabriel Alfonso Patron Herrera
# 2  Jesús Botero García,  Diego Montañez Herrera, ...
# 3  Jesús Alonso Botero García & Diego Fernando Mo...
# 4                                    Francisco Gómez
#
#                                           Unnamed: 2  \
# 0          <h4 style="text-align: center;">Tema</h4>
# 1  Principled Training of Generative Adversarial ...
# 2  Macroeconomía en los tiempos del COVID-19: un ...
# 3  Efectos en la economía colombiana del COVID-19...
# 4  Modelos de Predicción para Lesiones Personales...
#
# ...

# %%
df
# Out:
#                                      Unnamed: 0  \
# 0    <h4 style="text-align: center;">Fecha</h4>
# 1                           09 de Julio de 2020
# 2                               28 de mayo 2020
# 3                               28 de mayo 2020
# 4                                  22 Mayo 2020
# ..                                          ...
# 140                        14-Septiembre-2010\n
# 141                      21-Septiembre-2010\n\n
# 142                           26-Octubre-2010\n
# 143                            2-Noviembre-2010
# 144                            9-Noviembre-2010
#
#                                             Unnamed: 1  \
# 0       <h4 style="text-align: center;">Expositor</h4>
# 1                      Gabriel Alfonso Patron Herrera
# 2    Jesús Botero García,  Diego Montañez Herrera, ...
# 3    Jesús Alonso Botero García & Diego Fernando Mo...
# 4                                      Francisco Gómez
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df['Unnamed: 3'][1]
# Out:
# '<a href="https://quantil.co/wp-content/uploads/2020/08/Presentacion_tesis.pdf">Resumen</a>\n<a href="hhttps://youtu.be/p2beIrNg5Wg">Video</a>'
